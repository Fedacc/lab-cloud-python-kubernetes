# %% [markdown]
# # Title: this is the title of my notebook
#
# ## test
#
# This is a jupyter notebook of test

# %%
# note: you can issue commands to the underlying environment by adding an initial "!" to the first part of the line
# !python --version
# Out:
# Python 3.9.13

# %%
# !pip freeze
# Out:
# absl-py==0.12.0
# aiohttp==3.8.1
# aiosignal==1.2.0
# appdirs==1.4.4
# argon2-cffi==20.1.0
# astropy==5.0
# astunparse==1.6.3
# async-generator==1.10
# async-timeout==4.0.1
# attrs==21.2.0
# autoai-libs==1.13.6
# autoai-ts-libs==1.1.9
# autovizwidget==0.18.0
# av==8.0.3
# azure-core==1.21.0
# azure-cosmos==4.2.0
# backcall==0.2.0
# beautifulsoup4==4.10.0
# biopython==1.78
# black==19.10b0
# bleach==4.0.0
# blinker==1.4
# bokeh==2.3.3
# boto3==1.18.21
# botocore==1.21.41
# Bottleneck==1.3.2
# brotlipy==0.7.0
# ca-data-connector @ file:///tmp/ws-build/install/ca-data-connector-python-11.2.4.tgz
# cached-property==1.5.2
# cachetools==4.2.2
# cassandra-driver==3.25.0
# certifi==2022.9.24
# cffi==1.14.6
# charset-normalizer==2.0.4
# click==8.0.4
# cloudpickle==1.6.0
# cplex==20.1.0.2
# cryptography==3.4.8
# cx-Oracle==8.3.0
# cycler==0.11.0
# cytoolz==0.11.0
# dask==2021.10.0
# debugpy==1.5.1
# decision-optimization-client==1.0.0
# decorator==5.1.0
# defusedxml==0.7.1
# dill==0.3.4
# dm-tree==0.1.5
# docplex==2.22.213
# entrypoints==0.3
# et-xmlfile==1.1.0
# flatbuffers==2.0
# fonttools==4.25.0
# frozenlist==1.2.0
# fsspec==2021.10.1
# future==0.18.2
# gast==0.4.0
# gensim==4.1.2
# geographiclib==1.52
# geomet==0.2.1.post1
# geopy==2.2.0
# gmpy2==2.0.8
# google-auth==1.23.0
# google-auth-oauthlib==0.4.4
# google-pasta==0.2.0
# googleapis-common-protos==1.52.0
# graphviz==0.19
# greenery==3.3.2
# greenlet==1.1.1
# grpcio==1.42.0
# h5py==3.2.1
# hdijupyterutils==0.19.0
# html5lib==1.1
# hyperopt==0.2.5
# ibm-cloud-sdk-core==3.10.1
# ibm-cos-sdk==2.11.0
# ibm-cos-sdk-core==2.11.0
# ibm-cos-sdk-s3transfer==2.11.0
# ibm-data-fabric-sdk @ file:///tmp/ws-build/install/ibm_data_fabric_sdk-0.0.7-py3-none-any.whl
# ibm-db==3.1.0
# ibm-db-sa==0.3.7
# ibm-watson-machine-learning==1.0.255
# ibm-watson-openscale==3.0.24
# ibm-watson-studio-lib @ file:///tmp/ws-build/install/ibm-watson-studio-lib-py-3.0.10.tgz
# idna==3.3
# imagecodecs==2021.8.26
# imageio==2.9.0
# importlib-metadata==4.8.2
# iniconfig==1.1.1
# ipykernel==6.4.1
# ipython==7.29.0
# ipython-genutils==0.2.0
# ipywidgets==7.6.5
# itc-utils @ file:///tmp/ws-build/install/itc-library-python-0.1.14.tgz
# JayDeBeApi==1.2.3
# jedi==0.18.0
# Jinja2==3.0.2
# jmespath==0.10.0
# joblib==0.17.0
# JPype1==1.3.0
# jsonref==0.2
# jsonschema==3.2.0
# jsonsubschema==0.0.6
# jupyter==1.0.0
# jupyter-client==7.0.6
# jupyter-console==6.4.0
# jupyter-core==4.9.1
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==1.0.0
# keras==2.7.0
# Keras-Preprocessing==1.1.2
# kiwisolver==1.3.1
# lale==0.6.10
# lightgbm==3.3.2
# llvmlite==0.37.0
# locket==0.2.1
# lomond==0.3.3
# lxml==4.9.1
# Markdown==3.3.3
# MarkupSafe==2.0.1
# matplotlib==3.5.0
# matplotlib-inline==0.1.2
# mistune==0.8.4
# mlxtend==0.19.0
# mock==4.0.3
# mpmath==1.2.1
# multidict==5.2.0
# munkres==1.1.4
# mypy-extensions==0.4.3
# mysql-connector-python==8.0.28
# nbclient==0.5.3
# nbconvert==6.1.0
# nbformat==5.1.3
# nest-asyncio==1.5.1
# networkx==2.6.3
# nose==1.3.7
# notebook==6.4.11
# numba==0.54.1
# numexpr==2.8.1
# numpy==1.20.3
# oauthlib==3.2.1
# olefile==0.46
# onnx==1.10.2
# onnxconverter-common==1.9.0
# openpyxl==3.0.9
# opt-einsum==3.3.0
# packaging==21.3
# pandas==1.3.4
# pandocfilters==1.4.3
# parso==0.8.3
# partd==1.2.0
# pathspec==0.7.0
# patsy==0.5.2
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==9.0.1
# plotly==5.1.0
# pluggy==1.0.0
# portion==2.2.0
# portpicker==1.3.1
# project-lib @ file:///tmp/ws-build/install/project-lib-py-2.0.7.tgz
# prometheus-client==0.12.0
# prompt-toolkit==3.0.20
# protobuf==3.19.1
# psutil==5.8.0
# psycopg2==2.8.6
# ptyprocess==0.7.0
# py==1.10.0
# py4j==0.10.9.2
# pyarrow==5.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycparser==2.21
# pycryptodome==3.10.1
# pycryptodomex==3.10.1
# pyDeprecate==0.3.2
# pyerfa==2.0.0
# Pygments==2.10.0
# PyJWT==2.4.0
# pymssql==2.2.3
# pyodbc===4.0.0-unsupported
# pyOpenSSL==21.0.0
# pyparsing==3.0.4
# pyrsistent==0.18.0
# PySocks==1.7.1
# pyspnego==0.3.1
# pytest==6.2.5
# python-dateutil==2.8.2
# pytorch-lightning==1.6.5
# pytz==2021.3
# PyWavelets==1.1.1
# PyYAML==5.4.1
# pyzmq==22.3.0
# qtconsole==5.1.1
# QtPy==1.10.0
# regex==2021.11.2
# requests==2.26.0
# requests-kerberos==0.14.0
# requests-oauthlib==1.3.0
# rsa==4.7.2
# ruamel.yaml==0.16.12
# ruamel.yaml.clib==0.2.6
# s3transfer==0.5.0
# scikit-image==0.18.3
# scikit-learn==1.0.2
# scipy==1.7.3
# seaborn==0.11.2
# Send2Trash==1.8.0
# sentencepiece==0.1.96
# simplejson==3.17.6
# six==1.15.0
# skl2onnx==1.10.4
# smart-open==5.2.1
# snapml==1.8.8
# snowballstemmer==2.2.0
# sortedcontainers==2.4.0
# soupsieve==2.3.1
# sparkmagic==0.19.0
# SQLAlchemy==1.4.27
# statsmodels==0.12.2
# sympy==1.9
# tables==3.6.1
# tabulate==0.8.9
# tenacity==8.0.1
# tensorboard==2.7.0
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.6.0
# tensorflow==2.7.2
# tensorflow-addons==0.15.0
# tensorflow-estimator==2.7.0
# tensorflow-hub==0.12.0
# tensorflow-io-gcs-filesystem==0.23.1
# tensorflow-metadata==1.5.0
# tensorflow-probability==0.15.0
# tensorflow-text==2.7.3
# termcolor==1.1.0
# terminado==0.9.4
# testpath==0.5.0
# tf-model-optimization-nightly==0.7.0.dev20220726
# tf2onnx==1.9.3
# threadpoolctl==2.2.0
# tifffile==2021.7.2
# toml==0.10.2
# toolz==0.11.2
# torch==1.10.2
# torchmetrics==0.8.1
# torchtext==0.11.0a0+92f4d15
# torchvision==0.11.3
# tornado==6.1
# tqdm==4.62.3
# traitlets==5.1.1
# typed-ast==1.4.3
# typeguard==2.12.0
# typing_extensions==4.1.1
# urllib3==1.26.7
# wcwidth==0.2.5
# webencodings==0.5.1
# Werkzeug==2.0.2
# widgetsnbextension==3.5.1
# wrapt==1.12.1
# xgboost==1.5.2
# xlrd==2.0.1
# XlsxWriter==3.0.2
# yarl==1.6.3
# zipp==3.6.0

# %%
# !ls -l
# !pwd
# Out:
# total 0
# /home/wsuser/work

# %% [markdown]
# # NATURAL LANGUAGE UNDERSTANDING

# %% [markdown]
# ## API Call to the service using basic python modules
#
# TIP: use postman to obtain the python code for the API Call to Natural Language Understanding
# postman: https://www.postman.com/
# natural language understanding API documentation: https://cloud.ibm.com/apidocs/natural-language-understanding#introduction

# %%
# IMPORT DEPENDENCIES

import requests
import json

# DEFINE SOME USEFUL VARIABLES

NLU_BASEURL = "https://api.eu-de.natural-language-understanding.watson.cloud.ibm.com/instances/c5a51a57-f3d3-4779-baa4-49a6f7dd5eb8"
NLU_VERSION = "2022-04-07"
NLU_APIKEY = "APIKEY"

NLU_APIKEY_ENCODED = "APIKEY_ENCODED"  # encoding in base64 of the "string apikey:<NLU_APIKEY>"

SEARCH_URL = "https://en.wikipedia.org/wiki/Oryzomys_antillarum"


payload = json.dumps({
  "url": SEARCH_URL,
  "features": {
    "keywords": {
      "limit": 10
    }
  }
})

headers = {
  'Authorization': 'Basic ' + NLU_APIKEY_ENCODED,
  'Content-Type': 'application/json'
}

# INVOKE NLU VIA API and SELECT THE PROPER METHOD
response = requests.request("POST", NLU_BASEURL + "/v1/analyze?version=" + NLU_VERSION, headers=headers, data=payload)

print(response.text)
# Out:
# {
#   "usage": {
#     "text_units": 2,
#     "text_characters": 12858,
#     "features": 1
#   },
#   "retrieved_url": "https://en.wikipedia.org/wiki/Oryzomys_antillarum",
#   "language": "en",
#   "keywords": [
#     {
#       "text": "Oryzomys antillarum",
#       "relevance": 0.724445,
#       "count": 8
#     },
#     {
#       "text": "O. couesi of mainland Central America",
#       "relevance": 0.657966,
#       "count": 1
#     },
#     {
#       "text": "Jamaican rice rat",
#       "relevance": 0.64794,
#       "count": 1
#     },
#     {
#       "text": "member of the genus Oryzomys",
#       "relevance": 0.581761,
#       "count": 1
#     },
#     {
#       "text": "O. antillarum",
#       "relevance": 0.581662,
#       "count": 8
#     },
#     {
#       "text": "extinct rodent of Jamaica",
#       "relevance": 0.578255,
#       "count": 1
#     },
#     {
#       "text": "historical records of Jamaican rats",
#       "relevance": 0.566265,
#       "count": 1
#     },
#     {
#       "text": "Oryzomys couesi",
#       "relevance": 0.563389,
#       "count": 2
#     },
#     {
#       "text": "perforations of the front part of the palate",
#       "relevance": 0.552965,
#       "count": 1
#     },
#     {
#       "text": "body length",
#       "relevance": 0.551022,
#       "count": 1
#     }
#   ],
#   "warnings": [
#     "summarization: unsupported text language: en"
#   ]
# }

# %%
# CONVERT THE RESPONSE TO AN OBJECT WE CAN MANIPULATE
res_json = response.json()
print(res_json["retrieved_url"])
# Out:
# https://en.wikipedia.org/wiki/Oryzomys_antillarum

# %%
# print all the keywords

for keyword in res_json["keywords"]:
    print(keyword["text"])
# Out:
# Oryzomys antillarum
# O. couesi of mainland Central America
# Jamaican rice rat
# member of the genus Oryzomys
# O. antillarum
# extinct rodent of Jamaica
# historical records of Jamaican rats
# Oryzomys couesi
# perforations of the front part of the palate
# body length
